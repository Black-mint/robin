# %% [markdown]
# # Robin

# %%
import logging

from robin.assays import experimental_assay
from robin.candidates import therapeutic_candidates
from robin.configuration import RobinConfiguration

# %% [markdown]
# ## Robin Set Up

# %%
config = RobinConfiguration(disease_name="dry age-related macular degeneration")

logger = logging.getLogger("robin")
logger.setLevel(logging.INFO)

# %%
import os

from robin.configuration import RobinConfiguration
from robin.assays import experimental_assay
from robin.candidates import therapeutic_candidates

os.environ["ROBIN_LITERATURE_BACKEND"] = "openalex"

config = RobinConfiguration(
    application_domain="information_engineering",
    research_topic="retrieval augmented generation for software engineering",
)
config.set_llm_model("gemini/gemini-3.1-flash-lite")

# %% [markdown]
# # Initial therapeutics hypothesis generation

# %% [markdown]
# ### Experimental assay generation

# %%
candidate_generation_goal = await experimental_assay(configuration=config)
# Out:
# 2026-07-06 22:23:41,945 - robin.assays - INFO - Starting selection of a relevant experimental assay.
# 2026-07-06 22:23:41,945 - robin.assays - INFO - ------------------------------------------------------------
# 2026-07-06 22:23:41,945 - robin.assays - INFO -
# Step 1: Formulating relevant queries for literature search...
# 2026-07-06 22:23:45,803 - robin.assays - INFO - Generated Queries:
# 2026-07-06 22:23:45,804 - robin.assays - INFO - 1. Please provide the name of the `input_disease` you would like me to focus on. Since you did not specify one, I have drafted these queries using **Type 2 Diabetes (T2D)** as a placeholder template.
#
# ***
#
# Identify the primary molecular signaling pathways and cross-talk mechanisms—specifically involving insulin receptor substrate phosphorylation, mitochondrial dysfunction, and endoplasmic reticulum stress—that drive cellular insulin resistance in skeletal muscle and hepatic cell models, and evaluate how these define the current standard for phenotypic screening.
# 2026-07-06 22:23:45,805 - robin.assays - INFO - 2.  Define the essential requirements for developing high-throughput, physiologically relevant cell culture platforms, such as organ-on-a-chip or 3D organoid models, that accurately recapitulate the systemic metabolic interactions between adipocytes, hepatocytes, and myocytes to better assess drug efficacy and potential off-target toxicities.
# 2026-07-06 22:23:45,805 - robin.assays - INFO - 3.  Synthesize the latest advancements in longitudinal, real-time metabolic profiling techniques, including extracellular flux analysis and mass spectrometry-based metabolomics, that allow for the detection of subtle shifts in glucose flux, lipid metabolism, and insulin-stimulated glucose uptake in transformed versus primary cell lines within the context of metabolic syndrome research.
# 2026-07-06 22:23:45,806 - robin.assays - INFO -
# Step 2: Conducting literature search with Edison platform...
# 2026-07-06 22:23:46,473 - robin.utils - INFO - Starting literature search for 3 queries using job-futurehouse-paperqa3.
# 2026-07-06 22:23:47,330 - robin.utils - ERROR - Failed to submit task for query 'Please provide the name of the `input_disease` you would like me to focus on. Since you did not specify one, I have drafted these queries using **Type 2 Diabetes (T2D)** as a placeholder template.
#
# ***
#
# Identify the primary molecular signaling pathways and cross-talk mechanisms—specifically involving insulin receptor substrate phosphorylation, mitochondrial dysfunction, and endoplasmic reticulum stress—that drive cellular insulin resistance in skeletal muscle and hepatic cell models, and evaluate how these define the current standard for phenotypic screening. '
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:23:47,996 - robin.utils - ERROR - Failed to submit task for query ' Define the essential requirements for developing high-throughput, physiologically relevant cell culture platforms, such as organ-on-a-chip or 3D organoid models, that accurately recapitulate the systemic metabolic interactions between adipocytes, hepatocytes, and myocytes to better assess drug efficacy and potential off-target toxicities. '
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:23:48,679 - robin.utils - ERROR - Failed to submit task for query ' Synthesize the latest advancements in longitudinal, real-time metabolic profiling techniques, including extracellular flux analysis and mass spectrometry-based metabolomics, that allow for the detection of subtle shifts in glucose flux, lipid metabolism, and insulin-stimulated glucose uptake in transformed versus primary cell lines within the context of metabolic syndrome research.'
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:23:48,680 - robin.utils - INFO - Finished processing 0 tasks.
# 2026-07-06 22:23:48,683 - robin.assays - INFO -
# Step 3: Generating ideas for relevant experimental assays...
# 2026-07-06 22:24:00,978 - robin.assays - INFO - Strategy: High-Content Phenotypic Screening<|>Reasoning: High-content screening (HCS) using automate...
# 2026-07-06 22:24:00,980 - robin.assays - INFO - Strategy: Metabolic Flux Profiling<|>Reasoning: Many disease states are characterized by profound me...
# 2026-07-06 22:24:00,980 - robin.assays - INFO - Strategy: Reporter-Based Signaling Pathway Assay<|>Reasoning: Targeting dysregulated signaling nodes...
# 2026-07-06 22:24:00,984 - robin.assays - INFO - Successfully exported to robin_output/input_disease_2026-07-06_22-23-38/experimental_assay_summary.txt
# 2026-07-06 22:24:00,984 - robin.assays - INFO -
# Step 4: Detailed investigation and evaluation for each assay...
# 2026-07-06 22:24:00,985 - robin.utils - INFO - Starting literature search for 3 queries using job-futurehouse-paperqa3.
# 2026-07-06 22:24:01,704 - robin.utils - ERROR - Failed to submit task for query 'You are a professional biomedical researcher, having experience in early-stage drug discovery and validation in vitro. Your task is to evaluate cell culture assays that would be used to evaluate drugs to treat input_disease.
# Given the following assay, do a comprehensive literature review to evaluate if this assay would be useful for testing therapeutics for input_disease. Search relevant literature across
# biomedical, clinical, and biochemical literature about the disease or therapeutic landscape. Don't look up specific drugs, but any relevant scientific information that may inform assay development.Strategy: High-Content Phenotypic Screening
# Reasoning: High-content screening (HCS) using automated microscopy allows for the simultaneous quantification of multiple cellular parameters—such as nuclear morphology, organelle integrity, and cytoskeletal reorganization—providing a multidimensional readout of drug efficacy. By leveraging disease-relevant primary cells (e.g., patient-derived fibroblasts or iPSC-derived cells), HCS bridges the gap between target engagement and functional phenotype, allowing for the rapid identification of compounds that normalize disease-specific cellular signatures as documented in Nature Reviews Drug Discovery.Provide your response in the following format, like an evaluation for a scientific proposal:
# Assay Overview: Explain the assay idea, including the following key points: which aspect of the disease pathogenesis does the assay model, what measurements will be taken from the assay and how they will be taken, which cells or other biological material are used in the assay.
# Biomedical Evidence: Make a compelling argument for how the aspect of the disease represented in the assay is central to the pathogenesis of the disease. Make sure to consider both the biomedical and clinical literature.
# Previous Use: Explain how this assay has previously been used for drug discovery (if this has been done). Explain any key scientific discoveries which have been made using this assay.
# Overall Evaluation: Strengths and weaknesses of this assay for testing therapeutics for input_disease.'
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:24:02,292 - robin.utils - ERROR - Failed to submit task for query 'You are a professional biomedical researcher, having experience in early-stage drug discovery and validation in vitro. Your task is to evaluate cell culture assays that would be used to evaluate drugs to treat input_disease.
# Given the following assay, do a comprehensive literature review to evaluate if this assay would be useful for testing therapeutics for input_disease. Search relevant literature across
# biomedical, clinical, and biochemical literature about the disease or therapeutic landscape. Don't look up specific drugs, but any relevant scientific information that may inform assay development.Strategy: Metabolic Flux Profiling
# Reasoning: Many disease states are characterized by profound metabolic reprogramming, detectable via real-time analysis of the Extracellular Acidification Rate (ECAR) and Oxygen Consumption Rate (OCR) using instruments like the Seahorse XF analyzer. Measuring mitochondrial respiration and glycolytic capacity provides a direct functional readout of cellular health and stress responses. This strategy is highly relevant as metabolic plasticity is a common vulnerability in chronic and degenerative pathologies, enabling the identification of metabolic stabilizers or inhibitors that restore homeostatic bioenergetics.Provide your response in the following format, like an evaluation for a scientific proposal:
# Assay Overview: Explain the assay idea, including the following key points: which aspect of the disease pathogenesis does the assay model, what measurements will be taken from the assay and how they will be taken, which cells or other biological material are used in the assay.
# Biomedical Evidence: Make a compelling argument for how the aspect of the disease represented in the assay is central to the pathogenesis of the disease. Make sure to consider both the biomedical and clinical literature.
# Previous Use: Explain how this assay has previously been used for drug discovery (if this has been done). Explain any key scientific discoveries which have been made using this assay.
# Overall Evaluation: Strengths and weaknesses of this assay for testing therapeutics for input_disease.'
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:24:03,544 - robin.utils - ERROR - Failed to submit task for query 'You are a professional biomedical researcher, having experience in early-stage drug discovery and validation in vitro. Your task is to evaluate cell culture assays that would be used to evaluate drugs to treat input_disease.
# Given the following assay, do a comprehensive literature review to evaluate if this assay would be useful for testing therapeutics for input_disease. Search relevant literature across
# biomedical, clinical, and biochemical literature about the disease or therapeutic landscape. Don't look up specific drugs, but any relevant scientific information that may inform assay development.Strategy: Reporter-Based Signaling Pathway Assay
# Reasoning: Targeting dysregulated signaling nodes requires precise quantitative measurements of pathway activity. By engineering cell lines with sensitive, stable genetic reporter constructs—such as dual-luciferase or fluorescent proteins driven by pathway-specific promoters (e.g., NF-kB, Wnt, or SMAD)—one can assess real-time transcriptional modulation. This approach offers high signal-to-noise ratios, rapid turnaround, and robust suitability for high-throughput screening of libraries to identify potent modulators of specific pathogenic signaling cascades.Provide your response in the following format, like an evaluation for a scientific proposal:
# Assay Overview: Explain the assay idea, including the following key points: which aspect of the disease pathogenesis does the assay model, what measurements will be taken from the assay and how they will be taken, which cells or other biological material are used in the assay.
# Biomedical Evidence: Make a compelling argument for how the aspect of the disease represented in the assay is central to the pathogenesis of the disease. Make sure to consider both the biomedical and clinical literature.
# Previous Use: Explain how this assay has previously been used for drug discovery (if this has been done). Explain any key scientific discoveries which have been made using this assay.
# Overall Evaluation: Strengths and weaknesses of this assay for testing therapeutics for input_disease.'
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     async with httpx.AsyncClient(timeout=60) as client:
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 22:24:03,546 - robin.utils - INFO - Finished processing 0 tasks.
# 2026-07-06 22:24:03,547 - robin.assays - INFO -
# Step 5: Selecting the top experimental assay...
# 2026-07-06 22:24:03,549 - robin.utils - INFO - Starting comparisons for 3 pairs with max concurrency 100...
# Comparing Hypotheses:   0%|                                                    | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 candidate_generation_goal = await experimental_assay(configuration=config)
#
# File ~/robin/robin/assays.py:224, in experimental_assay(configuration)
#     220 assay_ranking_output_folder_path.mkdir(parents=True, exist_ok=True)
#     222 assay_pairs_list = uniformly_random_pairs(n_hypotheses=configuration.num_assays)
# --> 224 await run_comparisons(
#     225     pairs_list=assay_pairs_list,
#     226     client=configuration.llm_client,
#     227     system_prompt=assay_ranking_system_prompt,
#     228     ranking_prompt_format=assay_ranking_prompt_format,
#     229     assay_hypothesis_df=assay_hypothesis_df,
#     230     output_filepath=str(assay_ranking_output_filepath),
#     231 )
#     233 assay_ranking_df = processing_ranking_output(str(assay_ranking_output_filepath))
#     234 games_data = assay_ranking_df["Game Score"].to_list()
#
# File ~/robin/robin/utils.py:760, in run_comparisons(pairs_list, client, system_prompt, ranking_prompt_format, assay_hypothesis_df, output_filepath, max_concurrent_requests)
#     751     target_row = matching_rows.iloc[0]
#     753     return {
#     754         "hypothesis": str(target_row["hypothesis"]),
#     755         "answer": str(target_row["answer"]),
#     756         "index": str(target_row["index"]),
#     757     }
# --> 760 def uniformly_random_pairs(
#     761     n_hypotheses: int, seed: int = 621, n_games: int | None = None
#     762 ) -> list[tuple[int, int]]:
#     764     random.seed(seed)
#     766     MIN_HYPOTHESES = 2
#
# File ~/robin/.venv/lib/python3.12/site-packages/tqdm/asyncio.py:79, in tqdm_asyncio.gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      76     return i, await f
#      78 ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79 res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                          total=total, **tqdm_kwargs)]
#      81 return [i for _, i in sorted(res)]
#
# File /usr/lib/python3.12/asyncio/tasks.py:631, in as_completed.<locals>._wait_for_one()
#     628 if f is None:
#     629     # Dummy value from _on_timeout().
#     630     raise exceptions.TimeoutError
# --> 631 return f.result()
#
# File ~/robin/.venv/lib/python3.12/site-packages/tqdm/asyncio.py:76, in tqdm_asyncio.gather.<locals>.wrap_awaitable(i, f)
#      75 async def wrap_awaitable(i, f):
# ---> 76     return i, await f
#
# File ~/robin/robin/utils.py:627, in process_comparison_pair(pair, idx, semaphore, client, system_prompt, ranking_prompt_format, hypothesis_df)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/robin/robin/utils.py:434, in get_candidate_info(df, id_num)
#     432         logger.exception(f"Failed to submit task for query '{q}'")
#     433     except Exception:
# --> 434         logger.exception(f"Failed to submit task for query '{q}'")
#     436 completed_tasks_results = []
#     437 try:
#
# KeyError: "DataFrame is missing required columns: ['hypothesis', 'answer']"

# %% [markdown]
# ### Therapeutic candidate generation

# %%
await therapeutic_candidates(
    candidate_generation_goal=candidate_generation_goal, configuration=config
)
# Out:
# 2026-07-06 21:03:34,380 - robin.candidates - INFO - Starting generation of 5 therapeutic candidates.
# 2026-07-06 21:03:34,380 - robin.candidates - INFO - ------------------------------------------------------------
# 2026-07-06 21:03:34,381 - robin.candidates - INFO -
# Step 1: Formulating relevant queries for literature search...
# 2026-07-06 21:03:36,261 - robin.candidates - INFO - Generated Queries:
# 2026-07-06 21:03:36,263 - robin.candidates - INFO - 1. Comprehensive review of small-molecule screening assays designed to quantify retinal pigment epithelium phagocytosis, specifically focusing on kinetic protocols using photoreceptor outer segments, optimization of lysosomal acidification measurements, and established high-throughput phenotypic screening platforms for age-related macular degeneration drug discovery.
# 2026-07-06 21:03:36,264 - robin.candidates - INFO - 2.  Analysis of current pharmacological interventions and repurposed compounds aimed at restoring lysosomal proteostasis, autophagy flux, and phagocytic efficiency in retinal pigment epithelial cells, including evaluation of phenotypic screening hit validation pipelines and translational challenges in ocular delivery.
# 2026-07-06 21:03:36,264 - robin.candidates - INFO - 3.  Investigating the landscape of druggable targets within the endo-lysosomal and phagocytic pathways of the retinal pigment epithelium, specifically evaluating small-molecule modulators that rescue impaired clearance mechanisms in dry age-related macular degeneration models and assessing their pharmacological safety and pharmacokinetic profiles.
# 2026-07-06 21:03:36,265 - robin.candidates - INFO - 4.  Deep dive into the molecular pathology of RPE degeneration, focusing on the accumulation of lipofuscin and bisretinoids, the subsequent inhibition of lysosomal enzymatic activity, and the progressive failure of POS phagocytosis in dry age-related macular degeneration patient-derived cell models.
# 2026-07-06 21:03:36,266 - robin.candidates - INFO - 5.  Evaluation of genetic and biochemical drivers of retinal pigment epithelium senescence and metabolic dysfunction, specifically exploring the interplay between mitochondrial health, oxidative stress, and the downregulation of phagocytic receptors such as MERTK or Integrin alpha-v beta-5 in the progression of dry age-related macular degeneration.
# 2026-07-06 21:03:36,266 - robin.candidates - INFO - 6.  Examination of the crosstalk between inflammatory pathways, complement activation, and cellular clearance mechanisms in the retinal pigment epithelium, identifying how systemic and local immune signaling contributes to the chronic impairment of phagosomal degradation and visual cycle homeostasis in the context of geographic atrophy.
# 2026-07-06 21:03:36,266 - robin.candidates - INFO -
# Step 2: Conducting literature search with Edison platform...
# 2026-07-06 21:03:36,267 - robin.utils - INFO - Starting literature search for 6 queries using job-futurehouse-paperqa3.
# 2026-07-06 21:03:45,969 - robin.utils - ERROR - Failed to submit task for query ' Evaluation of genetic and biochemical drivers of retinal pigment epithelium senescence and metabolic dysfunction, specifically exploring the interplay between mitochondrial health, oxidative stress, and the downregulation of phagocytic receptors such as MERTK or Integrin alpha-v beta-5 in the progression of dry age-related macular degeneration. '
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     task_run_id = fh_client.create_task(task_data)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# 2026-07-06 21:03:46,625 - robin.utils - ERROR - Failed to submit task for query ' Examination of the crosstalk between inflammatory pathways, complement activation, and cellular clearance mechanisms in the retinal pigment epithelium, identifying how systemic and local immune signaling contributes to the chronic impairment of phagosomal degradation and visual cycle homeostasis in the context of geographic atrophy.'
# Traceback (most recent call last):
#   File "/home/yu/robin/robin/utils.py", line 115, in call_platform
#     task_run_id = fh_client.create_task(task_data)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 331, in wrapped_f
#     return copy(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 393, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/edison_client/clients/rest_client.py", line 692, in create_task
#     response.raise_for_status()
#   File "/home/yu/robin/.venv/lib/python3.12/site-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '402 Payment Required' for url 'https://api.platform.edisonscientific.com/v0.1/crows'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 await therapeutic_candidates(
#       2     candidate_generation_goal=candidate_generation_goal, configuration=config
#       3 )
#
# File ~/robin/robin/candidates.py:105, in therapeutic_candidates(candidate_generation_goal, configuration, experimental_insights)
#     101 # ### Step 2: Literature review on therapeutic candidates
#     103 logger.info("\nStep 2: Conducting literature search with Edison platform...")
# --> 105 therapeutic_candidate_review = await call_literature_platform(
#     106     queries=candidate_generation_queries_dict,
#     107     fh_client=configuration.edison_client,
#     108     job_name=configuration.agent_settings.candidate_lit_search_agent,
#     109 )
#     111 if experimental_insights:
#     112     save_crow_files(
#     113         therapeutic_candidate_review["results"],
#     114         run_dir=f"robin_output/{run_config_folder_name}/therapeutic_candidate_literature_reviews_experimental",
#     115         prefix="query",
#     116     )
#
# File ~/robin/robin/utils.py:130, in call_platform(queries, fh_client, job_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /usr/lib/python3.12/asyncio/tasks.py:520, in wait_for(fut, timeout)
#     517         raise TimeoutError from exc
#     519 async with timeouts.timeout(timeout):
# --> 520     return await fut
#
# File ~/robin/robin/utils.py:97, in gather_results(task_ids, fh_client)
#      91             logger.warning(f"Task {task_id} failed with status: {task_response.status}")
#      92             return task_response
#      95 async def gather_results(
#      96     task_ids: list[str], fh_client: EdisonClient
# ---> 97 ) -> list[TaskResponse | dict[str, str]]:
#      98     """Gathers results for multiple task IDs by polling concurrently."""
#      99     tasks = [poll_for_task_completion(t_id, fh_client) for t_id in task_ids]
#
# File ~/robin/robin/utils.py:77, in poll_for_task_completion(task_id, fh_client)
#      74     return task_response
#      75 if task_response.status in {"queued", "in progress"}:
#      76     logger.debug(
# ---> 77         f"Task {task_id} is still in progress (Status:"
#      78         f" {task_response.status}). Continuing poll..."
#      79     )
#      80     await asyncio.sleep(POLLING_INTERVAL)
#      81     continue
#
# File /usr/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %% [markdown]
# # Therapeutic hypothesis generation with experimental data

# %% [markdown]
# ### Running this part of Robin requires access to the Finch data analysis agent, which is currently in a closed beta. Sign up to be a beta tester here: [bit.ly/finchbeta](www.bit.ly/finchbeta). The `robin_full.ipynb notebook` shows an example of the usage of therapeutic hypothesis generation with experimental data.
